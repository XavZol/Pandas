# %%
import pandas as pd
import json as json

data = {
    'Nombre': ['Ana', 'Luis', 'Carlos', 'Sara'],
    'Edad': [25, 30, 52, 48],
    'Ciudad': ['Madrid', 'Barcelona', 'Valencia', 'Bilbao']
}
df = pd.DataFrame(data)
print(df)
# Out:
#    Nombre  Edad     Ciudad
# 0     Ana    25     Madrid
# 1    Luis    30  Barcelona
# 2  Carlos    52   Valencia
# 3    Sara    48     Bilbao

# %%
df['Salario'] = [30000, 40000, 80000, 40000]
df['Salario'] = df['Salario'] + 2000
print(df)
# Out:
#    Nombre  Edad     Ciudad  Salario
# 0     Ana    25     Madrid    32000
# 1    Luis    30  Barcelona    42000
# 2  Carlos    52   Valencia    82000
# 3    Sara    48     Bilbao    42000

# %%
nombre = df['Nombre']
print(nombre)
# Out:
# 0       Ana
# 1      Luis
# 2    Carlos
# 3      Sara
# Name: Nombre, dtype: str

# %%
mayores_25 = df[df['Edad'] >25]
print(mayores_25)
# Out:
#    Nombre  Edad     Ciudad  Salario
# 1    Luis    30  Barcelona    42000
# 2  Carlos    52   Valencia    82000
# 3    Sara    48     Bilbao    42000

# %%
edades = df['Edad']
print(edades)
# Out:
# 0    25
# 1    30
# 2    52
# 3    48
# Name: Edad, dtype: int64

# %%
mayores_25 = df[edades > 40]
print(mayores_25)
# Out:
#    Nombre  Edad    Ciudad  Salario
# 2  Carlos    52  Valencia    82000
# 3    Sara    48    Bilbao    42000

# %%
type(edades)
type(mayores_25)
# Out:
# pandas.DataFrame
