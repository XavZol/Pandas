# %%
import pandas as pd
import json as json


numeros = pd.Series([ 10, 20, 30 , 40, 50])
print(numeros)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
promedio = numeros.mean()
print(f"El promedio es {promedio}")
# Out:
# El promedio es 30.0

# %%
total = numeros.sum()
print(total)
# Out:
# 150

# %%
maximo = numeros.max()
print(maximo)
# Out:
# 50

# %%
minimo = numeros.min()
print(minimo)
# Out:
# 10
