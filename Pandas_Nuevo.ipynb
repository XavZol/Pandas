# %%
import pandas as pd
import json as json
serie = pd.Series([5 , 10 , 15 , 20 , 25])
print(serie)


# Los convertimos a booleanos
filtro = serie > 15
serie_filtrada = serie[filtro]
print(filtro)

# Indexamos los resultados ya convertidos
print(serie_filtrada)

serie2 = pd.Series(["banana", "pera", "melon", "manzana"])
print(serie2)


print(f"{dir(serie2.to_json)}")

type(serie2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import json as json
#       3 serie = pd.Series([5 , 10 , 15 , 20 , 25])
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.2.tar.gz (4.6 MB)
#      ---------------------------------------- 0.0/4.6 MB ? eta -:--:--
#      ---------------------- ----------------- 2.6/4.6 MB 29.4 MB/s eta 0:00:01
#      ---------------------------------------- 4.6/4.6 MB 29.4 MB/s  0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × installing build dependencies for pandas did not run successfully.
#   │ exit code: 1
#   ╰─> [127 lines of output]
#       Collecting meson-python<1,>=0.17.1
#         Downloading meson_python-0.19.0-py3-none-any.whl.metadata (2.1 kB)
#       Collecting meson<2,>=1.2.1
#         Downloading meson-1.10.2-py3-none-any.whl.metadata (1.8 kB)
#       Collecting wheel
#         Using cached wheel-0.46.3-py3-none-any.whl.metadata (2.4 kB)
#       Collecting Cython<4.0.0a0,>3.1.0
#         Downloading cython-3.2.4-py3-none-any.whl.metadata (7.3 kB)
#       Collecting numpy>=2.0.0
#         Downloading numpy-2.4.4.tar.gz (20.7 MB)
#            ---------------------------------------- 0.0/20.7 MB ? eta -:--:--
#            ------- -------------------------------- 3.9/20.7 MB 34.0 MB/s eta 0:00:01
#            --------------------- ----------------- 11.5/20.7 MB 34.9 MB/s eta 0:00:01
#            ----------------------------------- --- 18.9/20.7 MB 35.2 MB/s eta 0:00:01
#            ---------------------------------------- 20.7/20.7 MB 32.6 MB/s  0:00:00
#         Installing build dependencies: started
#         Installing build dependencies: finished with status 'done'
#         Getting requirements to build wheel: started
#         Getting requirements to build wheel: finished with status 'done'
#         Installing backend dependencies: started
#         Installing backend dependencies: finished with status 'done'
#         Preparing metadata (pyproject.toml): started
#         Preparing metadata (pyproject.toml): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × Preparing metadata (pyproject.toml) did not run successfully.
#         │ exit code: 2
#         ╰─> [89 lines of output]
#             + c:\Users\javie\AppData\Local\Programs\Python\Python315\python.exe C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54\vendored-meson\meson\meson.py setup C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54 C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54\.mesonpy-mj6ut2jp -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54\.mesonpy-mj6ut2jp\meson-python-native-file.ini
#             The Meson build system
#             Version: 1.9.2
#             Source dir: C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54
#             Build dir: C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54\.mesonpy-mj6ut2jp
#             Build type: native build
#             Activating VS 18.4.0
#             Project name: NumPy
#             Project version: 2.4.4
#             Exception in thread Thread-3 (_readerthread):
#             Exception in thread Thread-4 (_readerthread):
#             Traceback (most recent call last):
#               File "c:\Users\javie\AppData\Local\Programs\Python\Python315\Lib\threading.py", line 1075, in _bootstrap_inner
#                 self._context.run(self.run)
#                 ~~~~~~~~~~~~~~~~~^^^^^^^^^^
#               File "c:\Users\javie\AppData\Local\Programs\Python\Python315\Lib\threading.py", line 1017, in run
#                 self._target(*self._args, **self._kwargs)
#                 ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "c:\Users\javie\AppData\Local\Programs\Python\Python315\Lib\subprocess.py", line 1612, in _readerthread
#                 buffer.append(fh.read())
#                               ~~~~~~~^^
#               File "<frozen codecs>", line 325, in decode
#             UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa2 in position 24: invalid start byte
#             Traceback (most recent call last):
#               File "c:\Users\javie\AppData\Local\Programs\Python\Python315\Lib\threading.py", line 1075, in _bootstrap_inner
#                 self._context.run(self.run)
#                 ~~~~~~~~~~~~~~~~~^^^^^^^^^^
#               File "c:\Users\javie\AppData\Local\Programs\Python\Python315\Lib\threading.py", line 1017, in run
#                 self._target(*self._args, **self._kwargs)
#                 ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "c:\Users\javie\AppData\Local\Programs\Python\Python315\Lib\subprocess.py", line 1612, in _readerthread
#                 buffer.append(fh.read())
#                               ~~~~~~~^^
#               File "<frozen codecs>", line 325, in decode
#             UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe0 in position 104: invalid continuation byte
#             Traceback (most recent call last):
#               File "C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54\vendored-meson\meson\mesonbuild\mesonmain.py", line 193, in run
#                 return options.run_func(options)
#                        ~~~~~~~~~~~~~~~~^^^^^^^^^
#               File "C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54\vendored-meson\meson\mesonbuild\msetup.py", line 395, in run
#                 app.generate()
#                 ~~~~~~~~~~~~^^
#               File "C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54\vendored-meson\meson\mesonbuild\msetup.py", line 194, in generate
#                 return self._generate(env, capture, vslite_ctx)
#                        ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54\vendored-meson\meson\mesonbuild\msetup.py", line 236, in _generate
#                 intr = interpreter.Interpreter(b, user_defined_options=user_defined_options)
#               File "C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54\vendored-meson\meson\mesonbuild\interpreter\interpreter.py", line 310, in __init__
#                 self.parse_project()
#                 ~~~~~~~~~~~~~~~~~~^^
#               File "C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54\vendored-meson\meson\mesonbuild\interpreterbase\interpreterbase.py", line 138, in parse_project
#                 self.evaluate_codeblock(self.ast, end=1)
#                 ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#               File "C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54\vendored-meson\meson\mesonbuild\interpreterbase\interpreterbase.py", line 203, in evaluate_codeblock
#                 raise e
#               File "C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54\vendored-meson\meson\mesonbuild\interpreterbase\interpreterbase.py", line 195, in evaluate_codeblock
#                 self.evaluate_statement(cur)
#                 ~~~~~~~~~~~~~~~~~~~~~~~^^^^^
#               File "C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54\vendored-meson\meson\mesonbuild\interpreterbase\interpreterbase.py", line 209, in evaluate_statement
#                 return self.function_call(cur)
#                        ~~~~~~~~~~~~~~~~~~^^^^^
#               File "C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54\vendored-meson\meson\mesonbuild\interpreterbase\interpreterbase.py", line 536, in function_call
#                 res = func(node, func_args, kwargs)
#               File "C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54\vendored-meson\meson\mesonbuild\interpreterbase\decorators.py", line 237, in wrapper
#                 return f(*nargs, **wrapped_kwargs)
#               File "C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54\vendored-meson\meson\mesonbuild\interpreterbase\decorators.py", line 556, in wrapper
#                 return f(*wrapped_args, **wrapped_kwargs)
#               File "C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54\vendored-meson\meson\mesonbuild\interpreter\interpreter.py", line 1307, in func_project
#                 self.add_languages(proj_langs, True, MachineChoice.HOST)
#                 ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54\vendored-meson\meson\mesonbuild\interpreter\interpreter.py", line 1491, in add_languages
#                 success = self.add_languages_for(args, required, for_machine)
#               File "C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54\vendored-meson\meson\mesonbuild\interpreter\interpreter.py", line 1534, in add_languages_for
#                 comp = compilers.detect_compiler_for(self.environment, lang, for_machine, skip_sanity_check, self.subproject)
#               File "C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54\vendored-meson\meson\mesonbuild\compilers\detect.py", line 106, in detect_compiler_for
#                 comp = compiler_from_language(env, lang, for_machine)
#               File "C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54\vendored-meson\meson\mesonbuild\compilers\detect.py", line 103, in compiler_from_language
#                 return lang_map[lang](env, for_machine) if lang in lang_map else None
#                        ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#               File "C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54\vendored-meson\meson\mesonbuild\compilers\detect.py", line 633, in detect_c_compiler
#                 return _detect_c_or_cpp_compiler(env, 'c', for_machine)
#               File "C:\Users\javie\AppData\Local\Temp\pip-install-bbc1pkj7\numpy_7b01a41d79a74fc6a697b14964413c54\vendored-meson\meson\mesonbuild\compilers\detect.py", line 335, in _detect_c_or_cpp_compiler
#                 full_version = out.split('\n', 1)[0]
#                                ^^^^^^^^^
#             AttributeError: 'NoneType' object has no attribute 'split'
#
#             ..\meson.build:1:0: ERROR: Unhandled python exception
#
#                 This is a Meson bug and should be reported!
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: metadata-generation-failed
#
#       × Encountered error while generating package metadata.
#       ╰─> numpy
#
#       note: This is an issue with the package mentioned above, not pip.
#       hint: See above for details.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Failed to build 'pandas' when installing build dependencies for pandas

# %%
J
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 J
#
# NameError: name 'J' is not defined

# %%
j
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 j
#
# NameError: name 'j' is not defined

# %%
j
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 j
#
# NameError: name 'j' is not defined

# %%
json
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 json
#
# NameError: name 'json' is not defined

# %%
json{serie2}
# Out:
#   Cell In[5], line 1
#     json{serie2}
#         ^
# SyntaxError: invalid syntax

# %%
dir.json{serie2}
# Out:
#   Cell In[6], line 1
#     dir.json{serie2}
#             ^
# SyntaxError: invalid syntax

# %%
print(dir.json{serie2})
# Out:
#   Cell In[7], line 1
#     print(dir.json{serie2})
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
dir.json(serie2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dir.json(serie2)
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'json'

# %%
# %%
dir.json(serie2.to_json)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 # %%
# ----> 2 dir.json(serie2.to_json)
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'json'

# %%
# %%
dir(serie2.to_json).print(serie2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # %%
# ----> 2 dir(serie2.to_json).print(serie2)
#
# NameError: name 'serie2' is not defined

# %%
# %%
# %%
type(dir(serie2.to_json).print(serie2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 # %%
#       2 # %%
# ----> 3 type(dir(serie2.to_json).print(serie2))
#
# NameError: name 'serie2' is not defined
